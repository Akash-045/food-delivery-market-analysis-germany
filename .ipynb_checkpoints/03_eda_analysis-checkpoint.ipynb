# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/akashkumarsamantray/food-delivery-germany/food-delivery-market-analysis-germany/data/raw_reviews.csv')
df['at'] = pd.to_datetime(df['at'])
df.head()
# Out:
#                                reviewId           userName  \
# 0  06626e61-d64f-4e6c-933e-d581256aac7b     Sara Levermann
# 1  97aad388-9203-45eb-8499-db5de7b7e666        Matthias Ri
# 2  b96870a4-171e-48cc-bf40-3e4140b649cc         Jean Wolff
# 3  ec2966b1-2f78-4920-b4be-fb613c8b0689  Latifa Khennoussi
# 4  97cf249e-188c-4c95-88f6-0eef32b63e24    Wahid Alisaleha
#
#                                              content  score  thumbsUpCount  \
# 0                  Ich finde diese App sehr gut.🙂...      5              0
# 1  If anything goes wrong with an order don't exp...      1              0
# 2  Menü für 2 Personnen bestellt und gezahlt. Ein...      1              1
# 3                                          tolle App      5              0
# 4                                              Super      5              0
#
#                    at replyContent repliedAt appVersion app_name  review_year  \
# 0 2026-06-09 21:59:48     No Reply       NaN    26.23.3     Wolt         2026
# 1 2026-06-09 06:17:59     No Reply       NaN    26.22.3     Wolt         2026
# 2 2026-06-08 11:58:17     No Reply       NaN    26.22.3     Wolt         2026
# 3 2026-06-07 23:16:23     No Reply       NaN    26.22.3     Wolt         2026
# 4 2026-06-07 21:40:12     No Reply       NaN    26.22.3     Wolt         2026
#
#    review_month review_day  review_hour sentiment  review_length  word_count  \
# 0             6    Tuesday           21  Positive             33           6
# 1             6    Tuesday            6  Negative            107          17
# 2             6     Monday           11  Negative            409          60
# 3             6     Sunday           23  Positive              9           2
# 4             6     Sunday           21  Positive              5           1
#
#    has_reply
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
## Overall Rating Distribution

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='score', hue='app_name')
plt.title('Rating Distribution by App')
plt.show()

# %%
## Average score per app

df.groupby('app_name')['score'].agg(['mean', 'median', 'count'])
# Out:
#                 mean  median  count
# app_name
# Lieferando  2.966500     3.0   2000
# Uber Eats   1.704852     1.0   1999
# Wolt        3.434500     5.0   2000

# %%
## Sentiment Distribution Per app

sentiment_counts = df.groupby(['app_name', 'sentiment']).size().unstack()
sentiment_counts.plot(kind='bar', stacked=True, figsize=(8,5))
plt.title('Sentiment Distribution by App')
plt.ylabel('Count')
plt.show()
